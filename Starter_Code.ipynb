# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(columns=["EIN", "NAME"], inplace=True)

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df["APPLICATION_TYPE"].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`

application_type_counts = application_df['APPLICATION_TYPE'].value_counts()

application_types_to_replace = application_type_counts[application_type_counts < 500].index.tolist()

print(application_types_to_replace)
# Out:
# ['T9', 'T13', 'T12', 'T2', 'T25', 'T14', 'T29', 'T15', 'T17']

# %%
# Replace in dataframe
for app in application_types_to_replace:
    application_df["APPLICATION_TYPE"] = application_df["APPLICATION_TYPE"].replace(app,"Other")

# Check to make sure binning was successful
application_df["APPLICATION_TYPE"].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df["CLASSIFICATION"].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
application_df["CLASSIFICATION"].value_counts()[application_df["CLASSIFICATION"].value_counts() > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`

classifications_type_counts = application_df['CLASSIFICATION'].value_counts()

classifications_to_replace = classifications_type_counts[classifications_type_counts < 1000].index.tolist()

print(classifications_to_replace)
# Out:
# ['C7000', 'C1700', 'C4000', 'C5000', 'C1270', 'C2700', 'C2800', 'C7100', 'C1300', 'C1280', 'C1230', 'C1400', 'C7200', 'C2300', 'C1240', 'C8000', 'C7120', 'C1500', 'C1800', 'C6000', 'C1250', 'C8200', 'C1238', 'C1278', 'C1235', 'C1237', 'C7210', 'C2400', 'C1720', 'C4100', 'C1257', 'C1600', 'C1260', 'C2710', 'C0', 'C3200', 'C1234', 'C1246', 'C1267', 'C1256', 'C2190', 'C4200', 'C2600', 'C5200', 'C1370', 'C1248', 'C6100', 'C1820', 'C1900', 'C1236', 'C3700', 'C2570', 'C1580', 'C1245', 'C2500', 'C1570', 'C1283', 'C2380', 'C1732', 'C1728', 'C2170', 'C4120', 'C8210', 'C2561', 'C4500', 'C2150']

# %%
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_with_dummies_df = pd.get_dummies(application_df, columns=["APPLICATION_TYPE", "AFFILIATION", "CLASSIFICATION", "USE_CASE", "ORGANIZATION", "INCOME_AMT","SPECIAL_CONSIDERATIONS"])

application_with_dummies_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                       0
# 1       1   108590              1                       0
# 2       1     5000              0                       0
# 3       1     6692              1                       0
# 4       1   142590              1                       0
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                     1                     0                    0
# 1                     0                     0                    1
# 2                     0                     0                    0
# 3                     0                     0                    1
# 4                     0                     0                    1
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                    0                    0                    0  ...
# ...

# %%
# Split our preprocessed data into our features and target arrays
features_df = application_with_dummies_df.drop(columns="IS_SUCCESSFUL")
target_df = application_with_dummies_df["IS_SUCCESSFUL"]

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(features_df, target_df)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=43))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=30, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_23 (Dense)            (None, 80)                3520
#
#  dense_24 (Dense)            (None, 30)                2430
#
#  dense_25 (Dense)            (None, 1)                 31
#
# ...
# Total params: 5,981
# Trainable params: 5,981
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5664 - accuracy: 0.7260
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5523 - accuracy: 0.7306
# Epoch 3/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5484 - accuracy: 0.7324
# Epoch 4/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5466 - accuracy: 0.7343
# Epoch 5/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5454 - accuracy: 0.7346
# Epoch 6/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5450 - accuracy: 0.7336
# Epoch 7/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5441 - accuracy: 0.7357
# Epoch 8/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5431 - accuracy: 0.7364
# Epoch 9/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5428 - accuracy: 0.7367
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 2s - loss: 0.5858 - accuracy: 0.7231 - 2s/epoch - 7ms/step
# Loss: 0.5858391523361206, Accuracy: 0.7231487035751343

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity.h5")

# %%
# Another attempts to increase Accuracy.  Using drop_first to reduce the number of initial columns
application_2_df = pd.get_dummies(application_df, columns=["APPLICATION_TYPE", "AFFILIATION", "CLASSIFICATION", "USE_CASE", "ORGANIZATION", "INCOME_AMT","SPECIAL_CONSIDERATIONS"], drop_first=True)

application_2_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  \
# 0       1     5000              1                     1                     0
# 1       1   108590              1                     0                     0
# 2       1     5000              0                     0                     0
# 3       1     6692              1                     0                     0
# 4       1   142590              1                     0                     0
#
#    APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  \
# 0                    0                    0                    0
# 1                    1                    0                    0
# 2                    0                    0                    1
# 3                    1                    0                    0
# 4                    1                    0                    0
#
#    APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  ...  ORGANIZATION_Trust  \
# ...

# %%
# Split our preprocessed data into our features and target arrays
features_df = application_2_df.drop(columns="IS_SUCCESSFUL")
target_df = application_2_df["IS_SUCCESSFUL"]

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(features_df, target_df)

# %%
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Building the 2nd model,

nn_2 = tf.keras.models.Sequential()

# First hidden layer
nn_2.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=36))

# Second hidden layer - increasing neurons
nn_2.add(tf.keras.layers.Dense(units=80, activation="relu"))

# Adding a 3rd hidden layer - trying a different activation
nn_2.add(tf.keras.layers.Dense(units=80, activation="swish"))

# Output layer
nn_2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_2.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_26 (Dense)            (None, 80)                2960
#
#  dense_27 (Dense)            (None, 80)                6480
#
#  dense_28 (Dense)            (None, 80)                6480
#
#  dense_29 (Dense)            (None, 1)                 81
#
# ...
# Total params: 16,001
# Trainable params: 16,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_2.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5718 - accuracy: 0.7167
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5554 - accuracy: 0.7288
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5529 - accuracy: 0.7311
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5511 - accuracy: 0.7328
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5496 - accuracy: 0.7317
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5489 - accuracy: 0.7321
# Epoch 7/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5478 - accuracy: 0.7323
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5474 - accuracy: 0.7330
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5465 - accuracy: 0.7331
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5751 - accuracy: 0.7279 - 547ms/epoch - 2ms/step
# Loss: 0.5750754475593567, Accuracy: 0.7279300093650818

# %%
nn_2.save("AlphabetSoupCharity_2nd_try.h5")

# %%
# Very little improvement seen.  Trying again:

nn_3 = tf.keras.models.Sequential()

# First hidden layer
nn_3.add(tf.keras.layers.Dense(units=128, activation="relu", input_dim=36))

# Second hidden layer - increasing neurons
nn_3.add(tf.keras.layers.Dense(units=64, activation="relu"))

# Output layer
nn_3.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_3.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_30 (Dense)            (None, 128)               4736
#
#  dense_31 (Dense)            (None, 64)                8256
#
#  dense_32 (Dense)            (None, 1)                 65
#
# ...
# Total params: 13,057
# Trainable params: 13,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn_3.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
fit_model = nn_3.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# Exception ignored in: <function _xla_gc_callback at 0x7c6f22e3e560>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 98, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:
# 804/804 [==============================] - 52s 2ms/step - loss: 0.5710 - accuracy: 0.7201
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5577 - accuracy: 0.7291
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5539 - accuracy: 0.7278
# Epoch 4/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5523 - accuracy: 0.7304
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5512 - accuracy: 0.7312
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5495 - accuracy: 0.7332
# Epoch 7/100
# ...

# %%
model_loss, model_accuracy = nn_3.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5723 - accuracy: 0.7308 - 1s/epoch - 5ms/step
# Loss: 0.5722844004631042, Accuracy: 0.7308454513549805

# %%
nn_3.save("AlphabetSoupCharity_3rd_try.h5")
